# %% [markdown]
# # Part B. Python/OpenCV Practice:
# - Install Anaconda on your computer and use Jupyter Notebook as your
# programming environment. Make sure that Python, OpenCV, NumPy and
# Matplotlib are available.
# - Download at least two grayscale images from the Internet, or use your own
# grayscale images, then complete the following tasks.
# ## Task B1: Image reading, resizing, histogram equalization
# Read the downloaded images using OpenCV. If an image is a color image,
# convert it to grayscale. Then perform the following tasks:
# (a) Histogram and histogram equalization:
#
# - Compute and display the histogram of the grayscale image.
# - Apply histogram equalization to the grayscale image.
# - Compute and display the histogram of the equalized image.
#
# (b) Resize the grayscale image to 150% of its original width and height.
#
# (c) Display the following results:
#
# - original image;
# - grayscale image;
# - resized grayscale image;
# - histogram of the grayscale image;
# - equalized grayscale image;
# - histogram of the equalized grayscale image;
# - grayscale image and equalized grayscale image side by side for comparison.
#
# (d) Print the basic information of both the original image and the grayscale image, including:
# - image size;
# - number of channels;
# - data type;
# - minimum pixel value;
# - maximum pixel value.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread("jerry.jpg")
#Turn image into grayscale
print("Start gray...")
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        pixel = image[i][j]
        gray = int(int(pixel[0]) + int(pixel[1]) + int(pixel[2])) / 3
        pixel[0] = pixel[1] = pixel[2] = gray
print("Finish gray...")

cv2.imwrite("gray.jpg", image)
print("Saved gray")

original = cv2.imread("jerry.jpg")
original = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)

res = np.hstack((original, image))
plt.figure(figsize=(10, 5))
plt.imshow(res, cmap='gray')  
plt.title("Original vs Equalized Image")
plt.axis('off')  
plt.show()
# Out:
# Start gray...
# Finish gray...
# Saved gray

# %%
histg = cv2.calcHist([image], [0], None, [256], [0, 256])
plt.plot(histg)
plt.title("Histogram of original grayscale image")
plt.xlabel("Pixel intensity")
plt.ylabel("Frequency")
plt.show()

# %%
gray_img = cv2.imread("jerry.jpg", 0)
equa = cv2.equalizeHist(gray_img)
res = np.hstack((gray_img, equa))
plt.figure(figsize=(10,5))
plt.title("Grayscale image vs. Equalized grayscale image")
plt.imshow(res, cmap="gray")
#plt.axis("off")
plt.show()

# %%
histg = cv2.calcHist([equa], [0], None, [256], [0, 256])
plt.plot(histg)
plt.title("Histogram (Equalized)")
plt.xlabel("Pixel intensity")
plt.ylabel("Frequency")
plt.show()

# %%
resized = cv2.resize(image, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_LINEAR)
plt.imshow(resized)

# %%
print("Width:", image.shape[0])
print("Length:", image.shape[1])
print("Number of channels:", image.shape[2])
print("Type:", type(image))
# Out:
# Width: 853
# Length: 1080
# Number of channels: 3
# Type: <class 'numpy.ndarray'>

# %%
def findMaxMinPixel(image):
    max = min = image[0][0][0]
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            pixel = image[i][j]
            if pixel[0] > max:
                max = pixel[0]
            elif pixel[0] < min:
                min = pixel[0]
    res = [max, min]
    return res

print("Grayscale max pixel value:", findMaxMinPixel(image)[0])
print("Grayscale min pixel value:", findMaxMinPixel(image)[1])
# Out:
# Grayscale max pixel value: 192
# Grayscale min pixel value: 6

# %% [markdown]
# # Task B2: Brightness and contrast adjustment
# Change the brightness and contrast of the downloaded image using the
# following transformation:
# img_processed = a * f(x,y) + b
# In which, 𝑓(𝑥,𝑦) is the pixel value of the original image (𝑖𝑚𝑔) at the coordinate
# (𝑥, 𝑦); a is a user-defined contrast control parameter; b is a user-defined brightness
# control parameter. Apply the four following different pairs of (a,b):
# (a,b) = (1.0,50) or (1.0,−50) or (1.5,0) or (0.5,0)
# Then, complete the following tasks:
# - display the original and processed images;
# - display the histogram of each processed image;
# - compare the effects of different values of a and b;
# - explain how a affects contrast and how b affects brightness.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread("jerry.jpg")
#Turn image into grayscale
print("Start gray...")
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        pixel = image[i][j]
        gray = int(int(pixel[0]) + int(pixel[1]) + int(pixel[2])) / 3
        pixel[0] = pixel[1] = pixel[2] = gray
print("Finish gray...")
plt.imshow(image)
# Out:
# Start gray...
# Finish gray...

# %%
def transform(a, b, image):
    out = image.copy()
    for i in range(out.shape[0]):
        for j in range(out.shape[1]):
            pixel = out[i][j]
            s = a*int(pixel[0])+b
            if s > 255:
                s = 255
            elif s < 0:
                s = 0
            pixel[0] = pixel[1] = pixel[2] = s
    return out

# %%
transformed = transform(2.5, -5, image)
plt.imshow(transformed)
plt.show()

# %%
histg = cv2.calcHist([transformed], [0], None, [256], [0, 256])
plt.plot(histg)
plt.title("Transformation Histogram a = 2.5, b = -5")
plt.show()

# %% [markdown]
# # Task B3: Image Thresholding
# Perform image thresholding to convert a grayscale image into a binary image.
# - Read and display an image. If the selected image is a color image, convert it to grayscale first.
# - Display the histogram of the grayscale image.
# - Apply global thresholding using the three predefined following threshold values:
# T = 80 or 120 or 160
# - Display the binary images obtained from different threshold values.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def grayscaling(fName):
    image = cv2.imread(fName)
    print("Start gray...")
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            pixel = image[i][j]
            gray = int(int(pixel[0]) + int(pixel[1]) + int(pixel[2])) / 3
            pixel[0] = pixel[1] = pixel[2] = gray
    return image

image = cv2.imread("jerry.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

grayscale = grayscaling("jerry.jpg")

res = np.hstack((image, grayscale))
plt.imshow(res)
plt.title("Original vs. Grayscaled image")
plt.axis("off")
plt.show()
# Out:
# Start gray...

# %%
histg_2 = cv2.calcHist([grayscale], [0], None, [256], [0, 256])
plt.plot(histg_2, color="red", label="Grayscaled Image")
plt.title("Histogram of Grayscale Image")
plt.xlabel("Intensity")
plt.ylabel("Frequency")
plt.show()

# %%
def thresholding(gray_img, p):
    img = gray_img.copy()
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            pixel = img[i][j]
            if pixel[0] <= p:
                s = 0
            else:
                s = 255
            pixel[0] = pixel[1] = pixel[2] = s
    return img

thresh_img1 = thresholding(grayscale, 80)
thresh_img2 = thresholding(grayscale, 120)
thresh_img3 = thresholding(grayscale, 160)
res = np.hstack((thresh_img, thresh_img2, thresh_img3))
plt.imshow(res)
plt.title("Black and White images")
plt.axis("off")
plt.show()
